# %%
import pandas as pd
# Out:
# /usr/local/Cellar/python3/3.6.4_1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/Cellar/python3/3.6.4_1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
raw = pd.read_csv('reviews.csv')

# %%
raw
# Out:
#          company           location          dates  \
# 0         google               none   Dec 11, 2018
# 1         google  Mountain View, CA   Jun 21, 2013
# 2         google       New York, NY   May 10, 2014
# 3         google  Mountain View, CA    Feb 8, 2015
# 4         google    Los Angeles, CA   Jul 19, 2018
# 5         google  Mountain View, CA    Dec 9, 2018
# 6         google       New York, NY   Dec 11, 2018
# 7         google               none   Dec 11, 2018
# 8         google       New York, NY   Dec 10, 2018
# 9         google               none    Dec 9, 2018
# 10        google  Mountain View, CA    Dec 8, 2018
# 11        google               none    Dec 8, 2018
# 12        google               none    Dec 4, 2018
# 13        google  San Francisco, CA    Dec 3, 2018
# 14        google               none    Dec 6, 2018
# 15        google               none    Dec 6, 2018
# 16        google               none   Nov 29, 2018
# ...

# %%
company_overall_rating = raw[['company', 'overall-ratings']].groupby(['company'], as_index = False)['overall-ratings'].mean()

# %%
company_overall_rating
# Out:
#      company  overall-ratings
# 0     amazon         3.587363
# 1      apple         3.958224
# 2   facebook         4.511950
# 3     google         4.339430
# 4  microsoft         3.816564
# 5    netflix         3.411111

# %%
raw['company'].value_counts()
# Out:
# amazon       26430
# microsoft    17930
# apple        12950
# google        7819
# facebook      1590
# netflix        810
# Name: company, dtype: int64

# %%
raw['company'].unique().tolist()
# Out:
# ['google', 'amazon', 'facebook', 'netflix', 'apple', 'microsoft']

# %%
raw['work-balance-stars'].unique().tolist()
# Out:
# ['4.0', '2.0', '5.0', 'none', '3.0', '1.0', '4.5', '2.5', '3.5', '1.5']

# %%
raw['culture-values-stars'].unique().tolist()
# Out:
# ['5.0', '3.0', '4.0', 'none', '2.0', '1.0']

# %%
raw['carrer-opportunities-stars'].unique().tolist()
# Out:
# ['5.0', '3.0', '4.0', 'none', '2.0', '1.0', '3.5', '2.5', '4.5', '1.5']

# %%
raw['comp-benefit-stars'].unique().tolist()
# Out:
# ['4.0', '5.0', 'none', '3.0', '2.0', '1.0', '4.5', '3.5', '2.5', '1.5']

# %%
raw['senior-mangemnet-stars'].unique().tolist()
# Out:
# ['5.0', '3.0', '4.0', 'none', '1.0', '2.0', '4.5', '3.5', '2.5', '1.5']

# %%
raw.shape
# Out:
# (67529, 16)

# %%
raw.dtypes
# Out:
# company                        object
# location                       object
# dates                          object
# job-title                      object
# summary                        object
# pros                           object
# cons                           object
# advice-to-mgmt                 object
# overall-ratings               float64
# work-balance-stars             object
# culture-values-stars           object
# carrer-opportunities-stars     object
# comp-benefit-stars             object
# senior-mangemnet-stars         object
# helpful-count                   int64
# link                           object
# dtype: object

# %%
raw.isnull().sum()
# Out:
# company                         0
# location                        0
# dates                           0
# job-title                       0
# summary                       120
# pros                            0
# cons                            0
# advice-to-mgmt                297
# overall-ratings                 0
# work-balance-stars              0
# culture-values-stars            0
# carrer-opportunities-stars      0
# comp-benefit-stars              0
# senior-mangemnet-stars          0
# helpful-count                   0
# link                            0
# dtype: int64

# %%
len(raw['location'].unique().tolist())
# Out:
# 2044

# %%
location_none = raw.loc[raw['location'] == 'none']

# %%
location_none.shape
# Out:
# (25085, 16)

# %%
model_data = raw.loc[raw['work-balance-stars'] != 'none']
model_data = model_data.loc[raw['culture-values-stars'] != 'none']
model_data = model_data.loc[raw['carrer-opportunities-stars'] != 'none']
model_data = model_data.loc[raw['comp-benefit-stars'] != 'none']
model_data = model_data.loc[raw['senior-mangemnet-stars'] != 'none']

# %%
model_data.shape
# Out:
# (53222, 16)

# %%
#amazon_review = raw.loc[raw['company'] == 'amazon']

# %%
#amazon_review
# Out:
#       company                               location          dates  \
# 7819   amazon                            Phoenix, AZ           None
# 7820   amazon                          Sunnyvale, CA   Dec 10, 2018
# 7821   amazon                            Seattle, WA   Jan 10, 2016
# 7822   amazon                            Seattle, WA   Feb 20, 2016
# 7823   amazon                            Seattle, WA   Dec 17, 2013
# 7824   amazon                            Seattle, WA   Mar 23, 2017
# 7825   amazon                           Carlisle, PA   May 15, 2017
# 7826   amazon                            Seattle, WA   Mar 29, 2017
# 7827   amazon                            Seattle, WA    Dec 7, 2018
# 7828   amazon                                   none   Dec 10, 2018
# 7829   amazon                                   none   Dec 11, 2018
# 7830   amazon                                   none   Dec 11, 2018
# 7831   amazon                                   none   Dec 11, 2018
# ...

# %%
model_data
# Out:
#          company                location          dates  \
# 0         google                    none   Dec 11, 2018
# 1         google       Mountain View, CA   Jun 21, 2013
# 2         google            New York, NY   May 10, 2014
# 3         google       Mountain View, CA    Feb 8, 2015
# 4         google         Los Angeles, CA   Jul 19, 2018
# 5         google       Mountain View, CA    Dec 9, 2018
# 6         google            New York, NY   Dec 11, 2018
# 7         google                    none   Dec 11, 2018
# 8         google            New York, NY   Dec 10, 2018
# 9         google                    none    Dec 9, 2018
# 10        google       Mountain View, CA    Dec 8, 2018
# 11        google                    none    Dec 8, 2018
# 12        google                    none    Dec 4, 2018
# 13        google       San Francisco, CA    Dec 3, 2018
# 14        google                    none    Dec 6, 2018
# 16        google                    none   Nov 29, 2018
# ...

# %%
.groupby(['company'], as_index = False)['overall-ratings'].mean()

# %%
model_data1.head()
# Out:
#   company work-balance-stars culture-values-stars carrer-opportunities-stars  \
# 0  google                4.0                  5.0                        5.0
# 1  google                2.0                  3.0                        3.0
# 2  google                5.0                  4.0                        5.0
# 3  google                2.0                  5.0                        5.0
# 4  google                5.0                  5.0                        5.0
#
#   comp-benefit-stars senior-mangemnet-stars
# 0                4.0                    5.0
# 1                5.0                    3.0
# 2                5.0                    4.0
# 3                4.0                    5.0
# 4                5.0                    5.0

# %%
model_data1.dtypes
# Out:
# company                       object
# work-balance-stars            object
# culture-values-stars          object
# carrer-opportunities-stars    object
# comp-benefit-stars            object
# senior-mangemnet-stars        object
# dtype: object

# %%
model = model_data1.copy()

# %%
model.loc[:, 'work-balance-stars'] = model_data1['work-balance-stars'].astype(float).round()
model.loc[:, 'culture-values-stars'] = model_data1['culture-values-stars'].astype(float).round()
model.loc[:, 'carrer-opportunities-stars'] = model_data1['carrer-opportunities-stars'].astype(float).round()
model.loc[:, 'comp-benefit-stars'] = model_data1['comp-benefit-stars'].astype(float).round()
model.loc[:, 'senior-mangemnet-stars'] = model_data1['senior-mangemnet-stars'].astype(float).round()

# %%
model.dtypes
# Out:
# company                        object
# work-balance-stars            float64
# culture-values-stars          float64
# carrer-opportunities-stars    float64
# comp-benefit-stars            float64
# senior-mangemnet-stars        float64
# dtype: object

# %%
model['work-balance-stars'].unique().tolist()
# Out:
# [4.0, 2.0, 5.0, 3.0, 1.0]

# %%
model['culture-values-stars'].unique().tolist()
# Out:
# [5.0, 3.0, 4.0, 2.0, 1.0]

# %%
model['carrer-opportunities-stars'].unique().tolist()
# Out:
# [5.0, 3.0, 4.0, 2.0, 1.0]

# %%
model['comp-benefit-stars'].unique().tolist()
# Out:
# [4.0, 5.0, 3.0, 2.0, 1.0]

# %%
model['senior-mangemnet-stars'].unique().tolist()
# Out:
# [5.0, 3.0, 4.0, 1.0, 2.0]

# %%
model.head()
# Out:
#   company  work-balance-stars  culture-values-stars  \
# 0  google                 4.0                   5.0
# 1  google                 2.0                   3.0
# 2  google                 5.0                   4.0
# 3  google                 2.0                   5.0
# 4  google                 5.0                   5.0
#
#    carrer-opportunities-stars  comp-benefit-stars  senior-mangemnet-stars
# 0                         5.0                 4.0                     5.0
# 1                         3.0                 5.0                     3.0
# 2                         5.0                 5.0                     4.0
# 3                         5.0                 4.0                     5.0
# 4                         5.0                 5.0                     5.0

# %%
model.to_csv ('model.csv', index = False, header = True)

# %%
pingfen = model[['company','work-balance-stars','culture-values-stars',
                          'carrer-opportunities-stars', 'comp-benefit-stars','senior-mangemnet-stars']].groupby(['company'], as_index = False)['work-balance-stars','culture-values-stars', 
                                                                    'carrer-opportunities-stars', 'comp-benefit-stars','senior-mangemnet-stars'].mean()

# %%
pingfen
# Out:
#      company  work-balance-stars  culture-values-stars  \
# 0     amazon            3.010915              3.532292
# 1      apple            3.338017              4.097873
# 2   facebook            3.904729              4.515299
# 3     google            4.004104              4.359208
# 4  microsoft            3.575086              3.657359
# 5    netflix            3.210526              3.514170
#
#    carrer-opportunities-stars  comp-benefit-stars  senior-mangemnet-stars
# 0                    3.621241            3.710779                3.171875
# 1                    3.419399            4.059036                3.446916
# 2                    4.365090            4.573018                4.260779
# 3                    4.030692            4.427552                3.871877
# 4                    3.710211            4.025453                3.185432
# 5                    3.157895            4.257085                3.192308

# %%
pingfen.to_csv ('pingfen.csv', index = False, header = True)

# %%
company_rating = raw[['company', 'overall-ratings']].groupby(['company'], as_index = False)['overall-ratings'].mean()

# %%
model['company'].value_counts()
# Out:
# amazon       22080
# microsoft    13358
# apple        10248
# google        5604
# facebook      1438
# netflix        494
# Name: company, dtype: int64

# %%
from sklearn.utils import resample

# %%
# df_amazon = model.loc[model['company'] == 'amazon']
# df_microsoft = model.loc[model['company'] == 'microsoft']
# df_apple = model.loc[model['company'] == 'apple']
# df_google = model.loc[model['company'] == 'google']
# df_facebook = model.loc[model['company'] == 'facebook']
# df_netflix = model.loc[model['company'] == 'netflix']

# %%
# df_microsoft_downsampled = resample(df_microsoft, replace = True, n_samples = 22080, random_state=123)
# df_apple_downsampled = resample(df_apple, replace = True, n_samples = 22080, random_state=123)
# df_google_downsampled = resample(df_google, replace = True, n_samples = 22080, random_state=123)
# df_facebook_downsampled = resample(df_facebook, replace = True, n_samples = 22080, random_state=123)
# df_netflix_downsampled = resample(df_netflix, replace = True, n_samples = 22080, random_state=123)

# %%
# df_downsampled = pd.concat([df_amazon, df_microsoft_downsampled, df_apple_downsampled, 
#                             df_google_downsampled, df_facebook_downsampled, df_netflix_downsampled])

# %%
# df_amazon_downsampled = resample(df_amazon, replace = False, n_samples = 494, random_state=123)

# %%
#df_downsampled['company'].value_counts()
# Out:
# microsoft    22080
# netflix      22080
# facebook     22080
# amazon       22080
# google       22080
# apple        22080
# Name: company, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import matplotlib.pyplot as plt

# %%
model1 = model.drop(['company'], axis=1)

# %%
label = model[['company']]

# %%
print(len(model1),len(label))
# Out:
# 53222 53222

# %%
x = model1.iloc[:, :].values 
y = label.iloc[:, :].values

# %%
print(len(x), len(y))
# Out:
# 53222 53222

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
classifier = KNeighborsClassifier(n_neighbors=100)  
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=100, p=2,
#            weights='uniform')

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test, y_pred))  
print(classification_report(y_test, y_pred))
# Out:
# [[3793  278    0    0  354    0]
#  [1362  494    0    0  207    0]
#  [ 267   27    0    0   29    0]
#  [ 739  184    0    0  195    0]
#  [1857  186    0    0  581    0]
#  [  62   16    0    0   14    0]]
#              precision    recall  f1-score   support
#
#      amazon       0.47      0.86      0.61      4425
#       apple       0.42      0.24      0.30      2063
#    facebook       0.00      0.00      0.00       323
#      google       0.00      0.00      0.00      1118
#   microsoft       0.42      0.22      0.29      2624
#     netflix       0.00      0.00      0.00        92
#
# avg / total       0.38      0.46      0.38     10645
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from itertools import permutations

# %%
perm = permutations([1, 2, 3, 4, 5])

# %%
temp = list(perm)

# %%
temp
# Out:
# [(1, 2, 3, 4, 5),
#  (1, 2, 3, 5, 4),
#  (1, 2, 4, 3, 5),
#  (1, 2, 4, 5, 3),
#  (1, 2, 5, 3, 4),
#  (1, 2, 5, 4, 3),
#  (1, 3, 2, 4, 5),
#  (1, 3, 2, 5, 4),
#  (1, 3, 4, 2, 5),
#  (1, 3, 4, 5, 2),
#  (1, 3, 5, 2, 4),
#  (1, 3, 5, 4, 2),
#  (1, 4, 2, 3, 5),
#  (1, 4, 2, 5, 3),
#  (1, 4, 3, 2, 5),
#  (1, 4, 3, 5, 2),
#  (1, 4, 5, 2, 3),
#  (1, 4, 5, 3, 2),
#  (1, 5, 2, 3, 4),
#  (1, 5, 2, 4, 3),
#  (1, 5, 3, 2, 4),
#  (1, 5, 3, 4, 2),
#  (1, 5, 4, 2, 3),
#  (1, 5, 4, 3, 2),
#  (2, 1, 3, 4, 5),
#  (2, 1, 3, 5, 4),
#  (2, 1, 4, 3, 5),
#  (2, 1, 4, 5, 3),
#  (2, 1, 5, 3, 4),
#  (2, 1, 5, 4, 3),
#  (2, 3, 1, 4, 5),
#  (2, 3, 1, 5, 4),
#  (2, 3, 4, 1, 5),
#  (2, 3, 4, 5, 1),
#  (2, 3, 5, 1, 4),
#  (2, 3, 5, 4, 1),
#  (2, 4, 1, 3, 5),
#  (2, 4, 1, 5, 3),
#  (2, 4, 3, 1, 5),
#  (2, 4, 3, 5, 1),
#  (2, 4, 5, 1, 3),
#  (2, 4, 5, 3, 1),
#  (2, 5, 1, 3, 4),
#  (2, 5, 1, 4, 3),
#  (2, 5, 3, 1, 4),
#  (2, 5, 3, 4, 1),
#  (2, 5, 4, 1, 3),
#  (2, 5, 4, 3, 1),
#  (3, 1, 2, 4, 5),
#  (3, 1, 2, 5, 4),
# ...

# %%
request = []

# %%
for i in temp:
    request.append(list(i))

# %%
len(request)
# Out:
# 120

# %%
request
# Out:
# [[1, 2, 3, 4, 5],
#  [1, 2, 3, 5, 4],
#  [1, 2, 4, 3, 5],
#  [1, 2, 4, 5, 3],
#  [1, 2, 5, 3, 4],
#  [1, 2, 5, 4, 3],
#  [1, 3, 2, 4, 5],
#  [1, 3, 2, 5, 4],
#  [1, 3, 4, 2, 5],
#  [1, 3, 4, 5, 2],
#  [1, 3, 5, 2, 4],
#  [1, 3, 5, 4, 2],
#  [1, 4, 2, 3, 5],
#  [1, 4, 2, 5, 3],
#  [1, 4, 3, 2, 5],
#  [1, 4, 3, 5, 2],
#  [1, 4, 5, 2, 3],
#  [1, 4, 5, 3, 2],
#  [1, 5, 2, 3, 4],
#  [1, 5, 2, 4, 3],
#  [1, 5, 3, 2, 4],
#  [1, 5, 3, 4, 2],
#  [1, 5, 4, 2, 3],
#  [1, 5, 4, 3, 2],
#  [2, 1, 3, 4, 5],
#  [2, 1, 3, 5, 4],
#  [2, 1, 4, 3, 5],
#  [2, 1, 4, 5, 3],
#  [2, 1, 5, 3, 4],
#  [2, 1, 5, 4, 3],
#  [2, 3, 1, 4, 5],
#  [2, 3, 1, 5, 4],
#  [2, 3, 4, 1, 5],
#  [2, 3, 4, 5, 1],
#  [2, 3, 5, 1, 4],
#  [2, 3, 5, 4, 1],
#  [2, 4, 1, 3, 5],
#  [2, 4, 1, 5, 3],
#  [2, 4, 3, 1, 5],
#  [2, 4, 3, 5, 1],
#  [2, 4, 5, 1, 3],
#  [2, 4, 5, 3, 1],
#  [2, 5, 1, 3, 4],
#  [2, 5, 1, 4, 3],
#  [2, 5, 3, 1, 4],
#  [2, 5, 3, 4, 1],
#  [2, 5, 4, 1, 3],
#  [2, 5, 4, 3, 1],
#  [3, 1, 2, 4, 5],
#  [3, 1, 2, 5, 4],
# ...

# %%
request1 = np.asarray(request)
final_company = classifier.predict(request1)

# %%
final_company
# Out:
# array(['amazon', 'amazon', 'amazon', 'amazon', 'amazon', 'amazon',
#        'amazon', 'amazon', 'amazon', 'amazon', 'amazon', 'amazon',
#        'apple', 'apple', 'amazon', 'apple', 'amazon', 'amazon', 'apple',
#        'apple', 'amazon', 'amazon', 'amazon', 'amazon', 'amazon',
#        'amazon', 'amazon', 'amazon', 'amazon', 'amazon', 'amazon',
#        'amazon', 'amazon', 'amazon', 'amazon', 'amazon', 'apple', 'apple',
#        'amazon', 'microsoft', 'amazon', 'amazon', 'apple', 'apple',
#        'amazon', 'amazon', 'amazon', 'amazon', 'amazon', 'amazon',
#        'amazon', 'microsoft', 'amazon', 'amazon', 'amazon', 'amazon',
#        'amazon', 'microsoft', 'amazon', 'amazon', 'apple', 'apple',
#        'amazon', 'apple', 'amazon', 'amazon', 'apple', 'apple', 'amazon',
#        'apple', 'amazon', 'amazon', 'amazon', 'microsoft', 'amazon',
#        'microsoft', 'amazon', 'microsoft', 'amazon', 'microsoft',
#        'amazon', 'microsoft', 'amazon', 'microsoft', 'amazon',
# ...

# %%
for i in perm:
    print(i)

# %%
request_company = list(final_company)

# %%
request_company
# Out:
# ['amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'apple',
#  'apple',
#  'amazon',
#  'apple',
#  'amazon',
#  'amazon',
#  'apple',
#  'apple',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'apple',
#  'apple',
#  'amazon',
#  'microsoft',
#  'amazon',
#  'amazon',
#  'apple',
#  'apple',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'microsoft',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'amazon',
#  'microsoft',
#  'amazon',
#  'amazon',
#  'apple',
#  'apple',
#  'amazon',
#  'apple',
#  'amazon',
#  'amazon',
#  'apple',
#  'apple',
#  'amazon',
#  'apple',
#  'amazon',
#  'amazon',
#  'amazon',
#  'microsoft',
#  'amazon',
#  'microsoft',
# ...

# %%
request_int_list = []

# %%
for i in request:
    total = i[0] * 10000 + i[1] * 1000 + i[2] * 100 + i[3] * 10 + i[4]
    request_int_list.append(total)

# %%
len(request_int_list)
# Out:
# 120

# %%
final_request = pd.DataFrame(
    {'user_input': request_int_list,
     'company': request_company
    })

# %%
final_request.head()
# Out:
#    user_input company
# 0       12345  amazon
# 1       12354  amazon
# 2       12435  amazon
# 3       12453  amazon
# 4       12534  amazon

# %%
final_request.to_csv ('user_input.csv', index = False, header = True)

# %%
# Out:
# Text(0,0.5,'Mean Error')
